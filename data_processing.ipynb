# %%
from datasets import load_dataset, DatasetDict
from PIL import Image
import numpy as np
from torchvision import transforms
import torch
import matplotlib.pyplot as plt
from PIL import Image, ImageDraw

# %%
# Load the dataset
ds = load_dataset("visual-layer/oxford-iiit-pet-vl-enriched")

# Inspect the dataset
print(ds)
print(ds['train'][0])  # Example of a single sample
# Out:
# README.md:   0%|          | 0.00/5.91k [00:00<?, ?B/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/149M [00:00<?, ?B/s]
# test-00000-of-00001.parquet:   0%|          | 0.00/133M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/3680 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/3669 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['image_id', 'image', 'label_cat_dog', 'label_breed', 'caption_enriched', 'label_bbox_enriched', 'issues'],
#         num_rows: 3680
#     })
#     test: Dataset({
#         features: ['image_id', 'image', 'label_cat_dog', 'label_breed', 'caption_enriched', 'label_bbox_enriched', 'issues'],
#         num_rows: 3669
#     })
# })
# {'image_id': 'Maine_Coon_204', 'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=389x500 at 0x173E37550>, 'label_cat_dog': 'cat', 'label_breed': 'maine_coon', 'caption_enriched': 'a cat walking on grass', 'label_bbox_enriched': [{'bbox': [3, 3, 386, 497], 'label': 'cat'}], 'issues': []}

# %%
ds['train'][0]['image']
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=389x500>

# %%
TARGET_SIZE = 224  # Height, Width

def show_image_with_bbox(image, bbox, title=None):
    draw = ImageDraw.Draw(image)
    x, y, w, h = bbox
    draw.rectangle([x, y, x + w, y + h], outline="red", width=2)
    plt.imshow(image)
    if title:
        plt.title(title)
    plt.axis("off")
    plt.show()

def resize_and_pad(image, bbox):
    original_width, original_height = image.size

    # Compute scale to fit within 224x224
    scale = min(TARGET_SIZE / original_width, TARGET_SIZE / original_height)
    new_width = int(original_width * scale)
    new_height = int(original_height * scale)

    # Resize image
    resized_image = image.resize((new_width, new_height), Image.Resampling.LANCZOS)

    # Compute padding
    pad_x = (TARGET_SIZE - new_width) // 2
    pad_y = (TARGET_SIZE - new_height) // 2

    # Create new padded image
    new_image = Image.new("RGB", (TARGET_SIZE, TARGET_SIZE), (0, 0, 0))
    new_image.paste(resized_image, (pad_x, pad_y))

    # Update bbox: [x_min, y_min, width, height]
    x_min, y_min, box_width, box_height = bbox
    x_min = x_min * scale + pad_x
    y_min = y_min * scale + pad_y
    box_width *= scale
    box_height *= scale

    new_bbox = [x_min, y_min, box_width, box_height]
    return new_image, new_bbox

# %%
example = ds["train"][1]
image = example["image"]
bbox = example["label_bbox_enriched"][0]['bbox']
show_image_with_bbox(image, bbox, title=example["image_id"])
print(image.size)
resized_img, new_bbox = resize_and_pad(image, bbox)
show_image_with_bbox(resized_img, new_bbox, title=example["image_id"])
print(resized_img.size)
# Out:
# (333, 500)
# (224, 224)

# %%
def process_example(example):
    image = example['image']
    bbox_info = example['label_bbox_enriched'][0]  # assuming one box per image
    bbox = bbox_info['bbox']

    resized_img, new_bbox = resize_and_pad(image, bbox)

    # Update fields
    example['image'] = resized_img
    example['label_bbox_enriched'][0]['bbox'] = new_bbox
    return example

# %%
# Count how many have missing bboxes
missing_train = sum(1 for e in ds["train"] if e["label_bbox_enriched"] is None)
missing_test = sum(1 for e in ds["test"] if e["label_bbox_enriched"] is None)

print(f"Missing in train: {missing_train}")
print(f"Missing in test: {missing_test}")
# Out:
# Missing in train: 42
# Missing in test: 43

# %%
# Filter out examples without bbox
dataset_clean = DatasetDict({
    "train": ds["train"].filter(lambda e: e["label_bbox_enriched"] is not None),
    "test": ds["test"].filter(lambda e: e["label_bbox_enriched"] is not None)
})
# Out:
# Filter:   0%|          | 0/3680 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/3669 [00:00<?, ? examples/s]

# %%
# Apply processing to both splits
processed_dataset = DatasetDict({
    "train": dataset_clean["train"].map(process_example),
    "test": dataset_clean["test"].map(process_example)
})

# ✅ Optional: Visual check on a few processed samples
import matplotlib.pyplot as plt

def show_example(example):
    img = example['image']
    bbox = example['label_bbox_enriched'][0]['bbox']
    draw = ImageDraw.Draw(img)
    x, y, w, h = bbox
    draw.rectangle([x, y, x + w, y + h], outline="red", width=2)
    plt.imshow(img)
    plt.axis("off")
    plt.show()

# Show a few
for i in range(3):
    show_example(processed_dataset["train"][i])
# Out:
# Map:   0%|          | 0/3638 [00:00<?, ? examples/s]
# Map:   0%|          | 0/3626 [00:00<?, ? examples/s]

# %%
processed_dataset.save_to_disk("resized_oxford_pets_224")
# Out:
# Saving the dataset (0/1 shards):   0%|          | 0/3638 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/3626 [00:00<?, ? examples/s]
